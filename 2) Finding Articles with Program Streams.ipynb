# %% [markdown]
# # Exploring the Press Data
# ## 2) Finding Articles with Program Streams

# %%
import numpy as np
import pandas as pd

import pprint
import json
import bson

# %% [markdown]
# Define the functions to search for words in the list of articles and create a dictionary to store matches

# %%
# Determines whether the word occurs within the given list of strings
# returns True if so, and False if not
def is_word_in_string_list(list_of_strings, word):
    for line in list_of_strings:
        if line.find(word) != -1:
            return True
    return False

# %%
# Creates a dictionary of the list of articles that contain each word in the given list of words
# NOTE: this function assumes the incoming article objects have the same format as the raw articles stored 
# on MongoDB. That is, the full text is stored as a list of strings for each article object
# and can be accessed from the article object using "article_name['details']['fulltext']"
# If duplicate words are contained within the list of words, the function issues a warning,
# detailing which word occurs twice, but still continues processing
# input: list of search words, list of article objects
# output: dictionary of the list of articles containing each search word
def create_dictionary_of_articles(list_of_words, list_of_articles):
    
    article_dictionary = dict()
    
    # search for each word in the list of articles
    for word in list_of_words:
        
        # sanity check to make sure the list of words doesn't contain duplicates
        if word in article_dictionary:
            print("Warning: found a duplicate!", word)
            continue
        
        article_dictionary[word] = []
        
        # search through the articles for the word, and append the article to the dictionary if the word is found
        for article in list_of_articles:
            
            text = article['details']['fulltext']
            
            if is_word_in_string_list(text, word):
                article_dictionary[word].append(article)
        
        print("Found", len(article_dictionary[word]), "articles for", word)
        
    return article_dictionary

# %% [markdown]
# Get the list of program streams from the Programs excel spreadsheet

# %%
# read the Programs sheet
programs_list = pd.read_excel("./excel_sheets/Departments and Programs.xlsx", sheet_name = 'Programs')['Programs'].to_numpy()
programs_list = np.sort(programs_list)

# %%
print("Number of programs:", len(programs_list))
# Out:
# Number of programs: 144

# %% [markdown]
# Import the cleaned articles from the cleaned_articles.json file in the "data" directory, and convert the JSON objects into BSON objects for possible integration with MongoDB

# %%
with open('./data/cleaned_articles.json') as json_file:
    data = json.load(json_file)
    articles_json = data['cleaned_articles']

articles = []

# import function needed to convert JSON into BSON
from bson.json_util import loads

# convert the article from JSON into BSON
for article in articles_json:
    articles.append(loads(article))

# %% [markdown]
# Search for the program names in the list of articles, and store the results in a dictionary

# %%
results = create_dictionary_of_articles(programs_list, articles)
# Out:
# Found 89 articles for Accelerated Growth Service
# Found 16 articles for Advanced Manufacturing Fund
# Found 2 articles for Aerospace Program
# Found 0 articles for Agri-Science Clusters
# Found 6 articles for AgriInnovate Program
# Found 27 articles for AgriInnovation Program
# Found 39 articles for AgriMarketing Program
# Found 0 articles for AgriProcessing Initiative
# Found 34 articles for AgriScience Program
# Found 3 articles for Agricultural Clean Technology Program
# Found 14 articles for Agricultural Greenhouse Gases Program
# Found 0 articles for Agricultural Innovation Program
# Found 0 articles for Applied Research and Development Grants
# Found 2 articles for Aquaculture Collaborative Research and Development Program
# Found 0 articles for Aquatic and Crop Resource Development
# Found 37 articles for Atlantic Fisheries Fund
# Found 41 articles for Atlantic Innovation Fund
# Found 26 articles for Automotive Innovation Fund
# Found 0 articles for Automotive Supplier Innovation Fund
# Found 3 articles for Automotive and Surface Transportation
# Found 9 articles for British Columbia Salmon Restoration and Innovation Fund
# Found 43 articles for Build in Canada Innovation Program
# Found 0 articles for Buildings Infrastructure Program
# Found 509 articles for Business Development Program
# Found 0 articles for Business Development and Community Innovation
# Found 76 articles for Business Innovation
# Found 0 articles for Business-Led Network Centres of Excellence
# Found 1 articles for Business-Led Networks of Centres of Excellence
# Found 0 articles for CANARIE Inc.
# Found 127 articles for CanExport
# Found 17 articles for Canada Accelerator and Incubator Program
# Found 4 articles for Canada Business Network
# Found 6 articles for Canada Coal Transition Initiative
# Found 8 articles for Canada Small Business Financing Program
# Found 14 articles for Canadian Agricultural Adaptation Program
# Found 0 articles for Canadian Innovation Commercialization Program
# Found 3 articles for Canadian International Innovation Program
# Found 2 articles for Canadian Technology Accelerators
# Found 4 articles for Centre for Drug Research and Development
# Found 2 articles for Centres of Excellence for Commercialization and Research
# Found 1 articles for Clean Energy Fund
# Found 2 articles for Clean Energy for Rural and Remote Communities Program
# Found 19 articles for Clean Growth Hub
# Found 0 articles for Clean Growth in the Natural Resource Sectors Innovation Program
# Found 2 articles for Clean Technology Challenges
# Found 1 articles for Collaborative Economic Development Projects
# Found 1 articles for Collaborative Research and Development Grants
# Found 1 articles for Collaborative Science, Technology and Innovation Program
# Found 0 articles for College-University Idea to Innovation Grants
# Found 0 articles for Commercialization and Exports
# Found 2 articles for Communications Research Centre Canada
# Found 0 articles for Community Economic Development and Diversification
# Found 23 articles for Community Futures Program
# Found 0 articles for Connect Grants
# Found 169 articles for Construction
# Found 2 articles for Defence Innovation Research Program
# Found 0 articles for Developing Innovative Agricultural Products
# Found 0 articles for Earth Observation Application Development Program
# Found 3 articles for Eastern Ontario Development Program
# Found 65 articles for Economic Development Initiative
# Found 8 articles for Electric Vehicle and Alternative Fuel Infrastructure Deployment Initiative
# Found 0 articles for Emerging Renewables Power Program
# Found 5 articles for Energy Efficiency Program
# Found 7 articles for Energy Innovation Program
# Found 0 articles for Energy, Mining and Environment
# Found 1 articles for Engage Grants
# Found 11 articles for Entrepreneurship and Business Development
# Found 0 articles for Experience Awards
# Found 2 articles for Experimental Stream
# Found 10 articles for Fisheries and Aquaculture Clean Technology Adoption Program
# Found 9 articles for Forest Innovation Program
# Found 11 articles for Futurpreneur Canada
# Found 10 articles for Genome Canada
# Found 0 articles for GeoConnections
# Found 0 articles for GeoConnections Program
# Found 0 articles for Going Global Innovation
# Found 0 articles for Green Construction Through Wood Program
# Found 0 articles for Green Jobs - Science and Technology Internship Program
# Found 3 articles for Growing Forward 2 AgriMarketing Program
# Found 1 articles for Human Health Therapeutics
# Found 179 articles for Industrial Research Assistance Program
# Found 2 articles for Industrial Research Chairs
# Found 0 articles for Industry-Partnered Collaborative Research
# Found 5 articles for Information and Communication Technologies
# Found 0 articles for Innovation Enhancement Grants
# Found 52 articles for Innovation Superclusters Initiative
# Found 0 articles for Innovation and Technology Transfer
# Found 0 articles for Innovation for Defence, Excellence and Security
# Found 106 articles for Innovative Solutions Canada
# Found 0 articles for Innovative and Inclusive Economic Ecosystems
# Found 39 articles for Investing in Business Growth and Productivity
# Found 59 articles for Investing in Business Innovation
# Found 20 articles for Investing in Commercialization Partnerships
# Found 9 articles for Investing in Regional Diversification
# Found 14 articles for Investments in Forest Industry Transformation
# Found 44 articles for Low Carbon Economy Challenge
# Found 7 articles for Medical Devices
# Found 3 articles for Mining Innovation
# Found 2 articles for Mitacs Inc.
# Found 0 articles for Music Entrepreneur Component
# Found 0 articles for Network Structuring
# Found 0 articles for New Business Development and Start-Ups
# Found 2 articles for New Musical Works
# Found 1 articles for Northern Ontario Development Program
# Found 0 articles for Ocean, Coastal, and River Engineering
# Found 0 articles for Oil Spill Response Science Program
# Found 1 articles for Oil and Gas Clean Tech Program
# Found 0 articles for Pan North American Renewable Electricity Integration Studies
# Found 0 articles for Productivity and Expansion
# Found 0 articles for Productivity, Digitalization and Expansion
# Found 0 articles for Program of Energy, Research and Development
# Found 0 articles for Promotion Forest Innovation and Investment
# Found 0 articles for Proof of Principle Program
# Found 177 articles for Regional Economic Growth through Innovation
# Found 1 articles for Regional Growth through Innovation
# Found 8 articles for Science Horizons Youth Internship Program
# Found 2 articles for Science and Technology Internship Program
# Found 0 articles for Smart Grid Deployment Program
# Found 0 articles for Smart Grid Infrastructure Demonstrations Program
# Found 4 articles for Space Technology Development Program
# Found 1 articles for Stem Cell Network
# Found 10 articles for Strategic Aerospace and Defence Initiative
# Found 6 articles for Strategic Aerospace and Defence Initiative
# Found 126 articles for Strategic Innovation Fund
# Found 21 articles for Strategic Investments in Northern Economic Development
# Found 2 articles for Strategic Partnership Grants for Networks
# Found 4 articles for Strategic Partnership Grants for Projects
# Found 3 articles for Support for Publishers
# Found 55 articles for Sustainable Development Technology Canada
# Found 0 articles for Technology Access Centres Grants
# Found 9 articles for Technology Demonstration Program
# Found 1 articles for Technology Partnerships Canada
# Found 4 articles for Temporary Foreign Worker Program
# Found 305 articles for Trade Commissioner Service
# Found 0 articles for University Idea to Innovation Grants
# Found 94 articles for Western Diversification Program
# Found 23 articles for Western Innovation Initiative
# Found 53 articles for Women Entrepreneurship Fund
# Found 110 articles for Women Entrepreneurship Strategy
# Found 0 articles for Women's Entreprise Initiative
# Found 0 articles for eHealth Innovations Partnership Program
# Found 0 articles for ecoENERGY for Renewable Heat
# Found 0 articles for ecoENERGY for Renewable Power
# Found 0 articles for ecoEnergy Innovation Initiative

# %% [markdown]
# Exporting the results to a JSON file called *cleaned_articles_dictionary.json* in the **data** directory

# %%
# import function needed to convert BSON into JSON
from bson.json_util import dumps

# create a dictionary using JSON instead of BSON
results_json = dict()
for program in results:
    results_json[program] = []
    for article in results[program]:
        results_json[program].append(dumps(article))

data = dict()
data['cleaned_articles_dictionary'] = results_json

# save to the file (note, this re-writes the entire file)
with open('./data/cleaned_articles_dictionary.json', 'w') as outfile:
    json.dump(data, outfile)
